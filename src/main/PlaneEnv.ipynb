# %% [markdown]
# # HappyPlane Problem from RL point of View

# %% [markdown]
# ## Random Envirnoment-Executions Rewards

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from PlaneEnvironment import PlaneEnv

# %%
env = PlaneEnv('../../planes/plane1.txt')

# %%
iters = 200
rewards = []
for i in range(iters):
    env.reset()
    done = False
    reward = 0
    while (done == False):
        action = env.action_space_sample()
        (x, r, done, info) = env.step(action)
        reward += r
        #if (i%15):
        #    print(x)
        
    #env.plane.drawPlane()
    rewards.append(reward)
    #print("iter: " + str(i) + ", reward: " + str(reward))
    #print()

# %%
plt.subplots(figsize=(15,5))
plt.plot(rewards)
plt.title('Rewards. Random Case')
# Out:
# Text(0.5,1,'Rewards. Random Case')

# %% [markdown]
# ## Q-Learning Algorithm for passengers allocation

# %%
import numpy as np
from QLearningAlgorithm import QLearning

# %%
ql = QLearning('../../planes/plane1.txt')

# %%
s=10

# %%
totalrewards,_ = ql.launch(epsType='t2', slot=s, N=250)
# Out:
# episode: 9 total reward: 443.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# eps: 0.07374241268949282
# episode: 19 total reward: 360.0 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 29 total reward: 406.66666666666663 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 39 total reward: 513.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 49 total reward: 513.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 59 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 69 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 79 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 89 total reward: 410.0 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 99 total reward: 423.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 109 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 119 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 129 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 139 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 149 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 159 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 169 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 179 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 189 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 199 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 209 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 219 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 229 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 239 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# episode: 249 total reward: 493.3333333333333 ,iters: 16 ,ia1: 0 ia2: 0 ,ia3: 0
# ['1w ', '2 ', '3 ', '4 ']
# ['5 ', '6 ', '7 ', '8 ']
# ['13 ', '14 ', '15 ', '16 ']
# ['9w ', '10 ', '11 ', '12 ']

# %%
slot=s
plt.subplots(figsize=(18,5))
plt.plot(totalrewards)

N = len(totalrewards)
running_avg = np.empty(N)
for t in range(N):
    running_avg[t] = totalrewards[max(0, t-slot):(t+1)].mean()
plt.plot(running_avg)
plt.title("Rewards")
# Out:
# Text(0.5,1,'Rewards')

# %% [markdown]
# # End of evaluation!
