# %% [markdown]
# # HappyPlane Problem from RL point of View

# %% [markdown]
# ## Random Envirnoment-Executions Rewards

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from PlaneEnvironment import PlaneEnv

# %%
env = PlaneEnv('../../planes/plane1.txt')

# %%
iters = 200
rewards = []
for i in range(iters):
    env.reset()
    done = False
    while (done == False):
        action = env.action_space_sample()
        (x, reward, done, info) = env.step(action)
        #if (i%15):
        #    print(x)
        
    #env.plane.drawPlane()
    rewards.append(reward)
    #print("iter: " + str(i) + ", reward: " + str(reward))
    #print()

# %%
plt.plot(rewards)

# %% [markdown]
# ## Q-Learning Algorithm for passengers allocation

# %%
import numpy as np
from QLearningAlgorithm import QLearning

# %%
ql = QLearning('../../planes/plane1.txt')

# %%
s=10

# %%
(totalrewards,ia3s) = ql.launch(slot=s, N=100)
# Out:
# /Users/bernal/Documents/GitRepos/happyplane/src/main/QLearningAlgorithm.py:152: RuntimeWarning: Mean of empty slice.
#   print("avg reward for last ", slot, " episodes:", totalrewards[max(n-slot,0):n].mean())
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# avg reward for last  10  episodes: nan
# avg reward for last  10  episodes: 443.333333333
# avg reward for last  10  episodes: 433.333333333
# avg reward for last  10  episodes: 430.0
# avg reward for last  10  episodes: 428.333333333
# avg reward for last  10  episodes: 421.333333333
# avg reward for last  10  episodes: 413.333333333
# avg reward for last  10  episodes: 410.0
# avg reward for last  10  episodes: 416.25
# episode: 9 total reward: 306.66666666666663 ,iters: 133 ,ia1: 0 ia2: 0 ,ia3: 117
# ['1w ', '4 ', '11 ', '12 ']
# ['2 ', '5 ', '6 ', '7 ']
# ['3 ', '13 ', '14 ', '15 ']
# ['8 ', '9w ', '10 ', '16 ']
# avg reward for last  10  episodes: 407.777777778
# eps: 0.07374241268949282
# avg reward for last  10  episodes: 397.666666667
# avg reward for last  10  episodes: 392.333333333
# avg reward for last  10  episodes: 392.666666667
# avg reward for last  10  episodes: 384.333333333
# avg reward for last  10  episodes: 388.0
# avg reward for last  10  episodes: 393.0
# avg reward for last  10  episodes: 394.666666667
# avg reward for last  10  episodes: 395.0
# avg reward for last  10  episodes: 393.333333333
# episode: 19 total reward: 460.0 ,iters: 178 ,ia1: 0 ia2: 0 ,ia3: 162
# ['9w ', '13 ', '15 ', '16 ']
# ['2 ', '7 ', '8 ', '10 ']
# ['1w ', '11 ', '12 ', '14 ']
# ['3 ', '4 ', '5 ', '6 ']
# avg reward for last  10  episodes: 395.333333333
# avg reward for last  10  episodes: 410.666666667
# avg reward for last  10  episodes: 418.0
# avg reward for last  10  episodes: 417.666666667
# avg reward for last  10  episodes: 428.0
# avg reward for last  10  episodes: 426.333333333
# avg reward for last  10  episodes: 416.0
# avg reward for last  10  episodes: 416.0
# avg reward for last  10  episodes: 419.333333333
# avg reward for last  10  episodes: 416.0
# episode: 29 total reward: 390.0 ,iters: 353 ,ia1: 0 ia2: 0 ,ia3: 337
# ['5 ', '7 ', '13 ', '14 ']
# ['1w ', '2 ', '3 ', '4 ']
# ['11 ', '12 ', '15 ', '16 ']
# ['6 ', '8 ', '9w ', '10 ']
# avg reward for last  10  episodes: 422.666666667
# avg reward for last  10  episodes: 415.666666667
# avg reward for last  10  episodes: 405.333333333
# avg reward for last  10  episodes: 395.333333333
# avg reward for last  10  episodes: 388.333333333
# avg reward for last  10  episodes: 383.0
# avg reward for last  10  episodes: 389.666666667
# avg reward for last  10  episodes: 395.0
# avg reward for last  10  episodes: 391.333333333
# avg reward for last  10  episodes: 384.333333333
# episode: 39 total reward: 340.0 ,iters: 311 ,ia1: 0 ia2: 0 ,ia3: 295
# ['7 ', '10 ', '13 ', '16 ']
# ['8 ', '9w ', '14 ', '15 ']
# ['1w ', '6 ', '11 ', '12 ']
# ['2 ', '3 ', '4 ', '5 ']
# avg reward for last  10  episodes: 380.666666667
# avg reward for last  10  episodes: 375.666666667
# avg reward for last  10  episodes: 376.0
# avg reward for last  10  episodes: 388.0
# avg reward for last  10  episodes: 391.666666667
# avg reward for last  10  episodes: 391.666666667
# avg reward for last  10  episodes: 397.333333333
# avg reward for last  10  episodes: 385.666666667
# avg reward for last  10  episodes: 391.0
# avg reward for last  10  episodes: 396.333333333
# episode: 49 total reward: 340.0 ,iters: 278 ,ia1: 0 ia2: 0 ,ia3: 262
# ['1w ', '2 ', '5 ', '6 ']
# ['3 ', '7 ', '9w ', '10 ']
# ['4 ', '13 ', '14 ', '15 ']
# ['8 ', '11 ', '12 ', '16 ']
# avg reward for last  10  episodes: 398.333333333
# avg reward for last  10  episodes: 398.333333333
# avg reward for last  10  episodes: 406.333333333
# avg reward for last  10  episodes: 411.333333333
# avg reward for last  10  episodes: 411.333333333
# avg reward for last  10  episodes: 406.333333333
# avg reward for last  10  episodes: 399.0
# avg reward for last  10  episodes: 402.0
# avg reward for last  10  episodes: 388.333333333
# avg reward for last  10  episodes: 385.0
# episode: 59 total reward: 493.3333333333333 ,iters: 941 ,ia1: 0 ia2: 0 ,ia3: 925
# ['2 ', '3 ', '7 ', '8 ']
# ['9w ', '11 ', '12 ', '13 ']
# ['1w ', '4 ', '5 ', '6 ']
# ['10 ', '14 ', '15 ', '16 ']
# avg reward for last  10  episodes: 379.666666667
# avg reward for last  10  episodes: 395.0
# avg reward for last  10  episodes: 393.0
# avg reward for last  10  episodes: 382.666666667
# avg reward for last  10  episodes: 382.666666667
# avg reward for last  10  episodes: 387.666666667
# avg reward for last  10  episodes: 386.666666667
# avg reward for last  10  episodes: 396.666666667
# avg reward for last  10  episodes: 400.0
# avg reward for last  10  episodes: 396.333333333
# episode: 69 total reward: 390.0 ,iters: 101 ,ia1: 0 ia2: 0 ,ia3: 85
# ['3 ', '6 ', '9w ', '11 ']
# ['1w ', '2 ', '4 ', '5 ']
# ['13 ', '14 ', '15 ', '16 ']
# ['7 ', '8 ', '10 ', '12 ']
# avg reward for last  10  episodes: 394.666666667
# avg reward for last  10  episodes: 384.333333333
# avg reward for last  10  episodes: 381.0
# avg reward for last  10  episodes: 377.666666667
# avg reward for last  10  episodes: 376.0
# avg reward for last  10  episodes: 376.0
# avg reward for last  10  episodes: 379.0
# avg reward for last  10  episodes: 372.333333333
# avg reward for last  10  episodes: 379.333333333
# avg reward for last  10  episodes: 386.0
# episode: 79 total reward: 463.3333333333333 ,iters: 754 ,ia1: 0 ia2: 0 ,ia3: 738
# ['4 ', '6 ', '7 ', '9w ']
# ['10 ', '11 ', '13 ', '14 ']
# ['8 ', '12 ', '15 ', '16 ']
# ['1w ', '2 ', '3 ', '5 ']
# avg reward for last  10  episodes: 391.0
# avg reward for last  10  episodes: 398.333333333
# avg reward for last  10  episodes: 403.666666667
# avg reward for last  10  episodes: 407.0
# avg reward for last  10  episodes: 408.666666667
# avg reward for last  10  episodes: 408.666666667
# avg reward for last  10  episodes: 412.0
# avg reward for last  10  episodes: 417.0
# avg reward for last  10  episodes: 415.0
# avg reward for last  10  episodes: 418.666666667
# episode: 89 total reward: 463.3333333333333 ,iters: 974 ,ia1: 0 ia2: 0 ,ia3: 958
# ['10 ', '12 ', '13 ', '14 ']
# ['1w ', '2 ', '3 ', '7 ']
# ['4 ', '6 ', '8 ', '9w ']
# ['5 ', '11 ', '15 ', '16 ']
# avg reward for last  10  episodes: 419.0
# avg reward for last  10  episodes: 419.0
# avg reward for last  10  episodes: 413.666666667
# avg reward for last  10  episodes: 419.0
# avg reward for last  10  episodes: 417.333333333
# avg reward for last  10  episodes: 419.333333333
# avg reward for last  10  episodes: 414.0
# avg reward for last  10  episodes: 421.333333333
# avg reward for last  10  episodes: 418.333333333
# avg reward for last  10  episodes: 408.0
# episode: 99 total reward: 440.0 ,iters: 3505 ,ia1: 0 ia2: 0 ,ia3: 3489
# ['2 ', '5 ', '11 ', '13 ']
# ['7 ', '8 ', '10 ', '14 ']
# ['1w ', '3 ', '4 ', '6 ']
# ['9w ', '12 ', '15 ', '16 ']
# avg reward for last  10  episodes: 407.666666667
# ['2 ', '5 ', '11 ', '13 ']
# ['7 ', '8 ', '10 ', '14 ']
# ['1w ', '3 ', '4 ', '6 ']
# ['9w ', '12 ', '15 ', '16 ']

# %%
def plots(totalrewards, ia3,slot=100):
    plt.subplots(figsize=(18,5))
    plt.subplot(121)
    plt.plot(totalrewards)
    plt.subplot(122)    
    plt.subplot(122)
    plt.plot(ia3)
    plt.title("Ia3")

    N = len(totalrewards)
    running_avg = np.empty(N)
    for t in range(N):
        running_avg[t] = totalrewards[max(0, t-slot):(t+1)].mean()
    plt.subplot(121)
    plt.plot(running_avg)
    plt.title("Rewards")

# %%
plots(totalrewards, ia3s, slot=s)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # End of evaluation!
